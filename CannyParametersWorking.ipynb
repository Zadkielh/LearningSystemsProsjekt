# %%
# Import necessary libraries
import argparse
from tmu.preprocessing.standard_binarizer.binarizer import StandardBinarizer
import numpy as np
import cv2
from keras.datasets import cifar10
from tmu.models.classification.vanilla_classifier import TMClassifier
from time import time

# Load CIFAR-10 dataset
(X_train_org, Y_train), (X_test_org, Y_test) = cifar10.load_data()
# Out:
# 2023-12-01 10:45:42.896728: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 10:45:42.896782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 10:45:42.898401: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 10:45:42.907121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-01 10:45:43,789 - tensorflow - DEBUG - Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-12-01 10:45:44,093 - h5py._conv - DEBUG - Creating converter from 7 to 5
# 2023-12-01 10:45:44,094 - h5py._conv - DEBUG - Creating converter from 5 to 7
# 2023-12-01 10:45:44,095 - h5py._conv - DEBUG - Creating converter from 7 to 5
# 2023-12-01 10:45:44,095 - h5py._conv - DEBUG - Creating converter from 5 to 7
# 2023-12-01 10:45:44.026815: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-01 10:45:44,702 - numexpr.utils - INFO - Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# 2023-12-01 10:45:44,703 - numexpr.utils - INFO - Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2023-12-01 10:45:44,704 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.

# %%
# Copy the datasets
X_train = np.copy(X_train_org)
X_test = np.copy(X_test_org)

# Reshape labels
Y_train = Y_train.reshape(Y_train.shape[0])
Y_test = Y_test.reshape(Y_test.shape[0])

# Apply Canny edge detection and binarize images
for i in range(X_train.shape[0]):
    for j in range(X_train.shape[3]):
        edges = cv2.Canny(X_train[i, :, :, j], 100, 200)
        X_train[i, :, :, j] = np.where(edges != 0, 1, 0)

for i in range(X_test.shape[0]):
    for j in range(X_test.shape[3]):
        edges = cv2.Canny(X_test[i, :, :, j], 100, 200)
        X_test[i, :, :, j] = np.where(edges != 0, 1, 0)

# %%
# Other parameters
# Set specific values for T and s
T = 500
s = 5.0
num_clauses = 2000
max_included_literals = 32
device = "GPU"
weighted_clauses = True
epochs = 100
patch_size = 10
type_i_ii_ratio = 1.0

# Initialize TM Classifier with the chosen set of hyperparameters
tm = TMClassifier(
    number_of_clauses=num_clauses,
    T=T,
    s=s,
    max_included_literals=max_included_literals,
    platform=device,
    weighted_clauses=weighted_clauses,
    type_i_ii_ratio=type_i_ii_ratio,
    patch_dim=(patch_size, patch_size)
)

# Define the batch size
batch_size = 64  # You can adjust this based on your system's capabilities

# Function to yield batches from the dataset
def get_batches(X, Y, batch_size):
    for start in range(0, len(X), batch_size):
        end = start + batch_size
        yield X[start:end], Y[start:end]

# Train the TM Classifier with batch processing
for epoch in range(epochs):
    start_training = time()
    
    for X_batch, Y_batch in get_batches(X_train, Y_train, batch_size):
        tm.fit(X_batch, Y_batch)
    
    stop_training = time()

    # Evaluate the TM Classifier
    start_testing = time()
    Y_test_predicted, Y_test_scores = tm.predict(X_test, return_class_sums=True)
    stop_testing = time()
    result_test = 100 * (Y_test_scores.argmax(axis=1) == Y_test).mean()

    # Print accuracy for the current epoch
    print(f"Epoch {epoch+1} - Accuracy: {result_test:.2f}% - Training Time: {stop_training - start_training:.2f}s - Testing Time: {stop_testing - start_testing:.2f}s")
    np.savetxt("CIFAR10Canny_%d_%d_%d_%.1f_%d_%d_%d.txt" % (epoch+1, num_clauses, T, s, patch_size, max_included_literals, weighted_clauses), Y_test_scores, delimiter=',')
# Out:
# 2023-12-01 10:45:54,499 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:54,502 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:54,505 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:54,507 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:54,778 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:54,781 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:54,784 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:54,787 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:55,024 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:55,026 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:55,029 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:55,036 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:55,303 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:55,306 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:55,308 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:55,310 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:55,543 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:55,546 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:55,548 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:55,550 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:55,811 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:55,816 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:55,819 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:55,823 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:56,063 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:56,065 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:56,067 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:56,069 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:56,328 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:56,331 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:56,333 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:56,339 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:56,587 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:56,589 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:56,591 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:56,594 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# 2023-12-01 10:45:56,857 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5a9a47d4a1fe846aa3aafea0f0132d9ccd10af67.ptx'.
# 2023-12-01 10:45:56,860 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8346357baefab2be19365903c2ed3fd187dec2ea.ptx'.
# 2023-12-01 10:45:56,862 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/1aa20b9deb6b43a0d42ed539de0d0277f3f434e5.ptx'.
# 2023-12-01 10:45:56,865 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/5c7e6b0f3d143dc3a93f2f98e3cf780b40993aa3.ptx'.
# Epoch 1 - Accuracy: 34.69% - Training Time: 226.93s - Testing Time: 71.35s
# Epoch 2 - Accuracy: 42.39% - Training Time: 213.72s - Testing Time: 73.09s
# Epoch 3 - Accuracy: 44.12% - Training Time: 211.58s - Testing Time: 74.55s
# Epoch 4 - Accuracy: 42.67% - Training Time: 208.42s - Testing Time: 70.10s
# Epoch 5 - Accuracy: 43.87% - Training Time: 205.02s - Testing Time: 75.92s
# Epoch 6 - Accuracy: 44.73% - Training Time: 204.31s - Testing Time: 76.54s
# Epoch 7 - Accuracy: 44.37% - Training Time: 201.22s - Testing Time: 76.91s
# Epoch 8 - Accuracy: 44.96% - Training Time: 200.09s - Testing Time: 77.29s
# Epoch 9 - Accuracy: 45.74% - Training Time: 199.16s - Testing Time: 77.70s
# Epoch 10 - Accuracy: 44.63% - Training Time: 197.22s - Testing Time: 77.75s
# Epoch 11 - Accuracy: 45.75% - Training Time: 194.78s - Testing Time: 78.08s
# Epoch 12 - Accuracy: 43.93% - Training Time: 193.69s - Testing Time: 78.21s
# Epoch 13 - Accuracy: 45.94% - Training Time: 192.78s - Testing Time: 78.28s
# Epoch 14 - Accuracy: 45.89% - Training Time: 191.66s - Testing Time: 78.52s
# Epoch 15 - Accuracy: 46.55% - Training Time: 189.45s - Testing Time: 78.80s
# Epoch 16 - Accuracy: 46.42% - Training Time: 188.91s - Testing Time: 79.17s
# Epoch 17 - Accuracy: 46.86% - Training Time: 186.59s - Testing Time: 78.12s
# Epoch 18 - Accuracy: 45.50% - Training Time: 185.99s - Testing Time: 78.19s
# Epoch 19 - Accuracy: 46.82% - Training Time: 184.61s - Testing Time: 78.26s
# Epoch 20 - Accuracy: 46.23% - Training Time: 184.26s - Testing Time: 78.44s
# Epoch 21 - Accuracy: 46.93% - Training Time: 183.14s - Testing Time: 78.49s
# Epoch 22 - Accuracy: 46.82% - Training Time: 181.97s - Testing Time: 78.36s
# Epoch 23 - Accuracy: 46.84% - Training Time: 181.89s - Testing Time: 78.34s
# Epoch 24 - Accuracy: 46.44% - Training Time: 180.62s - Testing Time: 78.34s
# Epoch 25 - Accuracy: 46.63% - Training Time: 180.56s - Testing Time: 78.36s
# Epoch 26 - Accuracy: 47.61% - Training Time: 179.51s - Testing Time: 78.41s
# Epoch 27 - Accuracy: 46.67% - Training Time: 178.65s - Testing Time: 78.43s
# Epoch 28 - Accuracy: 46.59% - Training Time: 178.37s - Testing Time: 78.50s
# Epoch 29 - Accuracy: 47.12% - Training Time: 176.88s - Testing Time: 78.76s
# Epoch 30 - Accuracy: 46.15% - Training Time: 176.71s - Testing Time: 78.46s
# Epoch 31 - Accuracy: 46.89% - Training Time: 175.86s - Testing Time: 78.64s
# Epoch 32 - Accuracy: 47.22% - Training Time: 176.20s - Testing Time: 78.47s
# Epoch 33 - Accuracy: 46.99% - Training Time: 174.97s - Testing Time: 78.63s
# Epoch 34 - Accuracy: 46.20% - Training Time: 173.72s - Testing Time: 79.00s
# Epoch 35 - Accuracy: 46.79% - Training Time: 174.52s - Testing Time: 78.85s
# Epoch 36 - Accuracy: 47.28% - Training Time: 173.94s - Testing Time: 78.95s
# Epoch 37 - Accuracy: 47.26% - Training Time: 173.92s - Testing Time: 78.92s
# Epoch 38 - Accuracy: 46.47% - Training Time: 172.78s - Testing Time: 78.79s
# Epoch 39 - Accuracy: 47.91% - Training Time: 173.13s - Testing Time: 78.91s
# Epoch 40 - Accuracy: 47.68% - Training Time: 173.28s - Testing Time: 79.13s
# Epoch 41 - Accuracy: 47.47% - Training Time: 172.36s - Testing Time: 79.07s
# Epoch 42 - Accuracy: 47.96% - Training Time: 171.31s - Testing Time: 79.50s
# Epoch 43 - Accuracy: 47.23% - Training Time: 170.51s - Testing Time: 78.62s
# Epoch 44 - Accuracy: 47.89% - Training Time: 170.74s - Testing Time: 78.49s
# Epoch 45 - Accuracy: 47.59% - Training Time: 169.58s - Testing Time: 78.71s
# Epoch 46 - Accuracy: 47.06% - Training Time: 169.74s - Testing Time: 78.59s
# Epoch 47 - Accuracy: 46.57% - Training Time: 168.99s - Testing Time: 78.56s
# Epoch 48 - Accuracy: 47.68% - Training Time: 168.92s - Testing Time: 78.70s
# Epoch 49 - Accuracy: 47.60% - Training Time: 168.96s - Testing Time: 78.80s
# Epoch 50 - Accuracy: 47.31% - Training Time: 169.14s - Testing Time: 78.78s
# Epoch 51 - Accuracy: 48.09% - Training Time: 168.64s - Testing Time: 78.70s
